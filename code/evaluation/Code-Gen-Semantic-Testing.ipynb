# %% [markdown]
# This notebook provides the code to run the semantic tests for a given test file.

# %%
import unittest
from class_structure import *
from serialize import *
from test_statements import *
import pandas as pd

total_tests = 16

# %%
# Test cases for the class structure of a codebase

def test_all(self, gt_code, generated_code):
    """
    Run all tests on the generated code against the ground truth code.
    This function takes the following parameters:
    - self: The instance of the class containing the test methods
    - gt_code: The ground truth code to compare against
    - generated_code: The generated code to be tested
    Returns a tuple containing:
    - total_passed: Total number of tests passed
    - tp: True Positives
    - fp: False Positives
    - fn: False Negatives
    - mismatch: Mismatches
    """
    total_passed = 0 # tp + tn
    tp = 0
    fp = 0
    fn = 0
    mismatch = 0
    p, v = test_information_description(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_definition_term(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_definition_meaning(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_definition_exclusions(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_rule_entity(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_rule_type(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_rule_description(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_rule_conditions(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v=test_exemption_description(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_reference_relationship(self, gt_code, generated_code)
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='refines')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='is_refined_by')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='follows')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='is_followed_by')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='has_exception')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    p, v = test_statement_relationship(self, gt_code, generated_code, relation='is_exception_to')
    total_passed+=p
    if not p and v==1: fn+=1
    elif not p and v==2: mismatch+=1
    elif not p and not v: fp+=1
    elif p and v: tp+=1
    return total_passed, tp, fp, fn, mismatch

# %%
def calculate_distribution(df):
    """
    Calculate the distribution of test results across the dataframe.
    
    Returns:
      dist (dict): A dictionary containing the distribution of test results.
    """
    dist = {}
    for col in df.columns:
        if col in ['text', 'GT Code', 'Generated Code', 'Total Passed', 'True Positives', 'False Positives', 'False Negatives', 'Accuracy', 'Recall', 'Precision', 'Mismacthes']:
            continue
        counts = df[col].value_counts().to_dict()
        tp = 0
        fp = 0
        fn = 0
        passed = 0
        for key, value in counts.items():
            key = [int(k) for k in key[1:-1].split(', ')]
            if key[0]==1:
                passed += value
            if key[0]==1 and key[1]==1:
                tp += value
            elif key[0]==0 and (key[1]==0 or key[1]==2):
                fp += value
            elif key[0]==0 and (key[1]==1 or key[1]==2):
                fn += value
        acc = passed / len(df)
        recall = tp / (tp + fn) if (tp + fn) else None
        precision = tp / (tp + fp) if (tp + fp) else None
        dist[col] = { 'Accuracy': acc, 'Recall': recall, 'Precision': precision }
    return dist

def create_result_df(gt_df, gen_df):
    """
    Create a results dataframe that includes:
      - The original text, GT code, and generated code.
      - Overall test metrics (Total Passed, True Positives, False Positives, False Negatives).
      - Calculated Accuracy (Total Passed/total_tests), Recall, and Precision per row.
      - A mapping of individual test results for each test type.
      
    Returns:
      df_result (pd.DataFrame): The dataframe containing all the results.
      mean_accuracy (float): Average accuracy over all rows.
      mean_recall (float): Average recall over all rows.
      mean_precision (float): Average precision over all rows.
    """
    results = []
    total_accuracy = 0
    total_recall = 0
    total_precision = 0
    null_count_accuracy = 0
    null_count_recall = 0
    null_count_precision = 0

    for idx, gt_row in gt_df.iterrows():
        print(f"Row {idx}")
        # Retrieve corresponding values
        gt_code = gt_row['code']
        text = gt_row['text']
        gen_code = gen_df.loc[idx, 'code']
        
        # Create a test case instance to reuse for all tests on this row.
        test_case = unittest.TestCase()
        
        # Run the aggregated test function once per row
        total_passed, tp, fp, fn, mismatch = test_all(test_case, gt_code, gen_code)
        # Compute row metrics (with division safeguards)
        row_accuracy = total_passed / total_tests if total_tests else None
        row_recall = tp / (tp + fn + mismatch) if (tp + fn + mismatch) else None
        row_precision = tp / (tp + fp + mismatch) if (tp + fp + mismatch) else None

        total_accuracy += row_accuracy if row_accuracy is not None else 0
        total_recall += row_recall if row_recall is not None else 0
        total_precision += row_precision if row_precision is not None else 0
        if row_accuracy is None:
            null_count_accuracy += 1
        if row_recall is None:
            null_count_recall += 1
        if row_precision is None:
            null_count_precision += 1
        
        # Create mapping of individual test results.
        test_map = {
            'Information Description': test_information_description(test_case, gt_code, gen_code),
            'Definition Term': test_definition_term(test_case, gt_code, gen_code),
            'Definition Meaning': test_definition_meaning(test_case, gt_code, gen_code),
            'Definition Exclusions': test_definition_exclusions(test_case, gt_code, gen_code),
            'Rule Entity': test_rule_entity(test_case, gt_code, gen_code),
            'Rule Type': test_rule_type(test_case, gt_code, gen_code),
            'Rule Description': test_rule_description(test_case, gt_code, gen_code),
            'Rule Conditions': test_rule_conditions(test_case, gt_code, gen_code),
            'Exemption Description': test_exemption_description(test_case, gt_code, gen_code),
            'Refines': test_statement_relationship(test_case, gt_code, gen_code, relation='refines'),
            'Is Refined By': test_statement_relationship(test_case, gt_code, gen_code, relation='is_refined_by'),
            'Follows': test_statement_relationship(test_case, gt_code, gen_code, relation='follows'),
            'Is Followed By': test_statement_relationship(test_case, gt_code, gen_code, relation='is_followed_by'),
            'Exceptions': test_statement_relationship(test_case, gt_code, gen_code, relation='has_exception'),
            'Is Exception To': test_statement_relationship(test_case, gt_code, gen_code, relation='is_exception_to'),
            'References': test_reference_relationship(test_case, gt_code, gen_code)
        }
        
        # Build row dictionary
        row_data = {
            'text': text,
            'GT Code': gt_code,
            'Generated Code': gen_code,
            'Total Passed': total_passed,
            'Mismacthes': mismatch,
            'True Positives': tp,
            'False Positives': fp,
            'False Negatives': fn,
            'Accuracy': row_accuracy,
            'Recall': row_recall,
            'Precision': row_precision
        }
        # Merge test map into the row's data
        row_data.update(test_map)
        results.append(row_data)
    # Create dataframe from results and compute overall averages.
    df_result = pd.DataFrame(results)
    n = len(gt_df) 
    mean_accuracy = total_accuracy / (n - null_count_accuracy) if (n - null_count_accuracy) else 0
    mean_recall = total_recall / (n - null_count_recall) if (n - null_count_recall) else 0
    mean_precision = total_precision / (n - null_count_precision) if (n - null_count_precision) else 0
    
    return df_result, mean_accuracy, mean_recall, mean_precision

# %%
# Specify the paths to the ground truth and generated code files
gt_file = "/Users/singhal2/Downloads/Legal-FOL/Legal-Requirements-Translation/test files/OR.csv"
gen_file = "/Users/singhal2/Downloads/Legal-FOL/Legal-Requirements-Translation/code/intermediate-results/testing_set_pass_3_OR_gpt5.csv"

# Load the ground truth and generated code dataframes
gt_df = pd.read_csv(gt_file)
gen_df = pd.read_csv(gen_file)

# %%
# Ensure the 'code' column in both dataframes is properly formatted
gen_df['code'] = gen_df['code'].apply(
    lambda x: x.split("```")[1][7:].strip() if isinstance(x, str) and "```" in x else x
)

# %%
# Run the tests and create the result dataframe

df_result, m_accuracy, m_recall, m_precision = create_result_df(gt_df, gen_df)
print("Mean Accuracy: ", m_accuracy)
print("Mean Recall: ", m_recall)
print("Mean Precision: ", m_precision)
# Out:
# Row 0
# The two code snippets did not produce the same information description.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same information description.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 1
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 2
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 3
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 4
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 5
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 6
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# references test case passed
# Row 7
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# references test case passed
# Row 8
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# references test case passed
# Row 9
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 10
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 11
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 12
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 13
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 14
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 15
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 16
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 17
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 18
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# The two code snippets did not produce the same definition exclusions.
# Def exclusions test case failed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# is_exception_to test case passed
# references test case passed
# Row 19
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 20
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# references test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# references test case passed
# Row 21
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# The two code snippets did not produce the same number of exemption statements.
# Exemption test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# The two code snippets did not produce the same number of exemption statements.
# Exemption test case failed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 22
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# The two code snippets did not produce the same is_followed_by relationship list for each statement.
# is_followed_by test case failed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# The two code snippets did not produce the same is_exception_to relationship list for each statement.
# is_exception_to test case failed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# The two code snippets did not produce the same is_followed_by relationship list for each statement.
# is_followed_by test case failed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# The two code snippets did not produce the same is_exception_to relationship list for each statement.
# is_exception_to test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 23
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# The two code snippets did not produce the same definition meanings.
# Def meaning test case failed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 24
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 25
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 26
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 27
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# [{'text': 'notwithstanding subsection (1) of this section, a covered entity does not need to notify consumers of a breach of security if, after an appropriate investigation or after consultation with relevant federal, state or local law enforcement agencies, the covered entity reasonably determines that the consumers whose personal information was subject to the breach of security are unlikely to suffer harm.', 'includes': [], 'sectionNumber': '(8)'}]
# [{'text': 'notwithstanding subsection (1) of this section, a covered entity does not need to notify consumers of a breach of security', 'includes': [], 'sectionNumber': '(8)'}, {'text': 'if, after an appropriate investigation or after consultation with relevant federal, state or local law enforcement agencies, the covered entity reasonably determines that the consumers whose personal information was subject to the breach of security are unlikely to suffer harm', 'includes': [], 'sectionNumber': '(8)'}]
# The two code snippets did not produce the same exemption description.
# Exemption test case failed
# The two code snippets did not produce the same references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# [{'text': 'notwithstanding subsection (1) of this section, a covered entity does not need to notify consumers of a breach of security if, after an appropriate investigation or after consultation with relevant federal, state or local law enforcement agencies, the covered entity reasonably determines that the consumers whose personal information was subject to the breach of security are unlikely to suffer harm.', 'includes': [], 'sectionNumber': '(8)'}]
# [{'text': 'notwithstanding subsection (1) of this section, a covered entity does not need to notify consumers of a breach of security', 'includes': [], 'sectionNumber': '(8)'}, {'text': 'if, after an appropriate investigation or after consultation with relevant federal, state or local law enforcement agencies, the covered entity reasonably determines that the consumers whose personal information was subject to the breach of security are unlikely to suffer harm', 'includes': [], 'sectionNumber': '(8)'}]
# The two code snippets did not produce the same exemption description.
# Exemption test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same references.
# references test case failed
# Row 28
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# [{'text': 'this section does not apply to:', 'includes': [], 'sectionNumber': '(9)'}, {'text': "personal information that is subject to, and a person that complies with, notification requirements or procedures for a breach of security that the person's primary or functional federal regulator adopts, promulgates or issues in rules, regulations, procedures, guidelines or guidance, if the personal information and the person would otherwise be subject to ors 646a.600 to 646a.628", 'includes': [], 'sectionNumber': '(a)'}, {'text': 'personal information that is subject to, and a person that complies with, a state or federal law that provides greater protection to personal information and disclosure requirements at least as thorough as the protections and disclosure requirements provided under this section', 'includes': [], 'sectionNumber': '(b)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under title v of the gramm-leach-bliley act of 1999 (15 u.s.c. 6801 to 6809) as that act existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to that act', 'includes': [], 'sectionNumber': '(c)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under the health insurance portability and accountability act of 1996 (p.l. 104-191, 110 stat. 1936) and the health information technology for economic and clinical health act of 2009 (p.l. 111-5, title xiii, 123 stat. 226), as those acts existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to those acts', 'includes': [], 'sectionNumber': '(d)'}]
# [{'text': 'this section does not apply to:', 'includes': [], 'sectionNumber': '(9)'}, {'text': "personal information that is subject to, and a person that complies with, notification requirements or procedures for a breach of security that the person's primary or functional federal regulator adopts, promulgates or issues in rules, regulations, procedures, guidelines or guidance, if the personal information and the person would otherwise be subject to ors 646a.600 to 646a.628.", 'includes': [], 'sectionNumber': '(a)'}, {'text': 'personal information that is subject to, and a person that complies with, a state or federal law that provides greater protection to personal information and disclosure requirements at least as thorough as the protections and disclosure requirements provided under this section.', 'includes': [], 'sectionNumber': '(b)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under title v of the gramm-leach-bliley act of 1999 (15 u.s.c. 6801 to 6809) as that act existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to that act.', 'includes': [], 'sectionNumber': '(c)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under the health insurance portability and accountability act of 1996 (p.l. 104-191, 110 stat. 1936) and the health information technology for economic and clinical health act of 2009 (p.l. 111-5, title xiii, 123 stat. 226), as those acts existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to those acts.', 'includes': [], 'sectionNumber': '(d)'}]
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# The two code snippets did not produce the same is_exception_to relationship list for each statement.
# is_exception_to test case failed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# [{'text': 'this section does not apply to:', 'includes': [], 'sectionNumber': '(9)'}, {'text': "personal information that is subject to, and a person that complies with, notification requirements or procedures for a breach of security that the person's primary or functional federal regulator adopts, promulgates or issues in rules, regulations, procedures, guidelines or guidance, if the personal information and the person would otherwise be subject to ors 646a.600 to 646a.628", 'includes': [], 'sectionNumber': '(a)'}, {'text': 'personal information that is subject to, and a person that complies with, a state or federal law that provides greater protection to personal information and disclosure requirements at least as thorough as the protections and disclosure requirements provided under this section', 'includes': [], 'sectionNumber': '(b)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under title v of the gramm-leach-bliley act of 1999 (15 u.s.c. 6801 to 6809) as that act existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to that act', 'includes': [], 'sectionNumber': '(c)'}, {'text': 'a covered entity or vendor that complies with regulations promulgated under the health insurance portability and accountability act of 1996 (p.l. 104-191, 110 stat. 1936) and the health information technology for economic and clinical health act of 2009 (p.l. 111-5, title xiii, 123 stat. 226), as those acts existed on january 1, 2020, if personal information that is subject to ors 646a.600 to 646a.628 is also subject to those acts', 'includes': [], 'sectionNumber': '(d)'}]
# ...
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 54
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 55
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# The two code snippets did not produce the same rule type.
# Rule type test case failed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# The two code snippets did not produce the same rule type.
# Rule type test case failed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 56
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same references.
# references test case failed
# refines test case passed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# refines test case passed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same references.
# references test case failed
# Row 57
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# The two code snippets did not produce the same is_exception_to relationship list for each statement.
# is_exception_to test case failed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# The two code snippets did not produce the same rule description.
# Rule description test case failed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# The two code snippets did not produce the same has_exception relationship list for each statement.
# has_exception test case failed
# The two code snippets did not produce the same is_exception_to relationship list for each statement.
# is_exception_to test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 58
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of statements.
# refines test case failed
# The two code snippets did not produce the same number of statements.
# is_refined_by test case failed
# The two code snippets did not produce the same number of statements.
# follows test case failed
# The two code snippets did not produce the same number of statements.
# is_followed_by test case failed
# The two code snippets did not produce the same number of statements.
# has_exception test case failed
# The two code snippets did not produce the same number of statements.
# is_exception_to test case failed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 59
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# The two code snippets did not produce the same rule conditions.
# Rule condition test case failed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 60
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# refines test case passed
# is_refined_by test case passed
# follows test case passed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Row 61
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of information statements.
# Info description test case failed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# The two code snippets did not produce the same number of rule statements.
# Rule entity test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule type test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule description test case failed
# The two code snippets did not produce the same number of rule statements.
# Rule condition test case failed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# The two code snippets did not produce the same is_refined_by relationship list for each statement.
# is_refined_by test case failed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# The two code snippets did not produce the same number of references.
# references test case failed
# Row 62
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# references test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# Info description test case passed
# Definition test case passed
# Def meaning test case passed
# Def exclusions test case passed
# Rule entity test case passed
# Rule type test case passed
# Rule description test case passed
# Rule condition test case passed
# Exemption description test case passed
# The two code snippets did not produce the same refines relationship list for each statement.
# refines test case failed
# is_refined_by test case passed
# The two code snippets did not produce the same follows relationship list for each statement.
# follows test case failed
# is_followed_by test case passed
# has_exception test case passed
# is_exception_to test case passed
# references test case passed
# Mean Accuracy:  0.7569444444444444
# Mean Recall:  0.5602619162142972
# Mean Precision:  0.543241370622323

# %%
# Save the result dataframe to a CSV file

df_result.to_csv("intermediate-results/semantic_test_3_OR.csv", index=False)
